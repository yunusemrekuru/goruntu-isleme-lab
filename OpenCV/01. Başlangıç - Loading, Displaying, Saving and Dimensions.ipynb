# %% [markdown]
# # **Başlangıç**
#
# İlk OpenCV dersinize hoş geldiniz. Burada şunları öğreneceğiz:
# 1. OpenCV Modelini Python'a Aktarma
# 2. Resimleri Yükleme
# 3. Resimleri Görüntüleme
# 4. Resimleri Kaydetme
# 5. Resim Boyutlarını Alma

# %%
#OpenCV'yi bu şekilde içe aktarıyoruz, önce bunu yapmadan OpenCV'nin fonksiyonlarını kullanamayız
import cv2

# %%
#Hangi sürümü çalıştırdığımıza bakalım.
print(cv2.__version__)
# Out:
# 4.12.0

# %% [markdown]
# ### **Görselleri İndirme**
#
# Google Colab kullanıyorsanız, resim dosyalarını yüklememiz** gerekecek.
#
# Colab, Google'ın sunucularını kullanarak **bulutta** çalışan bir Jupyther Notebook ortamıdır. Bu nedenle, kullanmak istediğimiz herhangi bir dosyanın kendi sunucularına yüklenmesi gerekir.
#
# Eğer yerelde çalışıyorsanız resim dosyalarını doğru yerde bulundurmanız yeterli olacaktır.

# %%
#### Silinecek bas
# Download and unzip our images
#!wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
#!gdown --id 1O2uCujErifjvK1ziRGssaQO9khI15g6q
#!unzip -qq images.zip
##### Silinecek bit

#resim dosyaları OpenCV klasörünün yanında bulunan(bulunması gereken) files klasörüünün içinde images alt klasöründedir. 
#Aşağıdaki komutu çalıştırınca resim dosyalarının isimlerini görüyorsanız files klasörü olması gereken yerdedir.
# !dir ..\files\images
# Out:
#  Volume in drive Y is Yeni Birim
#  Volume Serial Number is F43F-E775
#
#  Directory of y:\MASA�ST�\BilgisayarliGoru2025.V01\files\images
#
# 16.09.2025  20:02    <DIR>          .
# 16.09.2025  20:02    <DIR>          ..
# 17.11.2020  20:10            12.292 .DS_Store
# 08.09.2025  11:31            79.365 1024px-ISBN.jpg
# 08.09.2025  11:28           439.449 1DwED.jpg
# 30.08.2016  00:02             7.247 4star.jpg
# 16.09.2016  00:35            99.829 abraham.jpg
# 15.09.2025  11:22             7.093 abraham_mask.png
# 01.10.2016  16:33            10.909 beatle.jpg
# 16.09.2025  20:02            71.290 biden.jpg
# 16.09.2025  20:02           153.326 biden2.jpg
# 17.11.2020  01:20           102.334 blacksandbeach.jpeg
# 30.08.2016  06:16            38.127 blobs.jpg
# 18.11.2020  20:50           500.705 boat.jpg
# 18.11.2020  20:50            29.492 boat_mask.jpg
# 30.08.2016  21:36           585.589 bottlecaps.jpg
# 06.11.2014  04:49           122.490 box_in_scene.png
# 30.08.2016  04:10            34.129 bunchofshapes.jpg
# 20.08.2025  15:06            18.529 cameraman.jpg
# 30.08.2016  05:28           588.203 candy.jpg
# 04.09.2016  06:04         2.253.706 cars.avi
# 17.11.2020  01:19           195.589 castara.jpeg
# 30.08.2016  05:49            38.885 chess.JPG
# 31.08.2016  01:21             4.850 chihuahua.jpg
# 17.11.2020  01:20            80.789 church_iceland.jpeg
# 20.08.2025  22:54            82.585 Circles_Packed_In_Square_11.jpeg
# 18.11.2020  20:51           392.132 city.jpg
# 18.11.2020  20:50            15.334 city_mask.jpg
# 08.09.2016  07:55             5.523 coffee.jpg
# 17.11.2020  01:18           114.690 coffee_view.jpeg
# 08.09.2016  16:31           101.595 contours.jpg
# 17.11.2020  01:20           141.054 cups.jpeg
# 06.11.2014  04:49           721.129 digits.png
# 01.10.2016  16:38            12.074 domino.png
# 30.08.2016  19:38             3.176 download.png
# 17.09.2016  06:21           175.184 eigenface_reconstruction_opencv.png
# 07.09.2016  07:53           196.567 elephant.jpg
# 08.09.2016  08:45            40.393 ex2.jpg
# 09.10.2016  22:24           133.781 faceswap.JPG
# 17.11.2020  01:20           147.541 fireworks.jpeg
# 17.11.2020  01:20           130.054 fireworks2.jpeg
# 17.11.2020  01:20           252.864 flowers.jpeg
# 08.09.2016  05:20            10.876 gradient.jpg
# 30.08.2016  19:39            16.867 hand.jpg
# 12.08.2016  03:06             5.834 Hillary.jpg
# 17.11.2020  07:35            66.650 hilton.jpeg
# 29.08.2016  23:51            37.142 house.jpg
# 17.11.2020  01:18           201.084 houseonhill.jpeg
# 17.11.2020  01:20            80.612 iceland_rum.jpeg
# 30.08.2016  05:16         2.281.975 IMG_7539.jpg
# 20.09.2014  12:39         7.292.637 IMG_8295.JPG
# 30.08.2016  05:17           237.310 input.jpg
# 30.08.2016  05:10            46.620 input33.JPG
# 04.10.2016  02:44             6.315 kim.jpg
# 17.11.2020  01:19           155.964 liberty.jpeg
# 17.11.2020  01:19           229.997 londonxmas.jpeg
# 17.11.2020  01:19           223.589 londonxmas2.jpeg
# 30.08.2016  07:50           213.571 lourve_noise.jpg
# 05.04.2018  18:45            11.027 LP.jpg
# 09.09.2016  18:54            62.494 marsface.jpg
# 16.09.2016  03:28           143.292 mask.jpg
# 28.08.2016  00:01           115.043 numbers.jpg
# 17.09.2016  06:14           157.690 obama.jpg
# 17.09.2016  06:16            36.663 obamafacerecog.jpg
# 19.11.2020  00:48            13.250 OCR1.png
# 19.11.2020  00:48            13.104 OCR2.png
# 19.11.2020  00:48           185.406 OCR3.png
# 29.09.2016  17:16            12.759 opencv.png
# 29.09.2016  17:19             8.031 opencv_inv.png
# 07.08.2016  03:38            99.629 Origin_of_Species.jpg
# 24.03.2016  03:37           247.120 output.jpg
# 17.11.2020  01:19           239.895 oxfordlibrary.jpeg
# 16.09.2016  04:47           237.538 photorestore.JPG
# 17.11.2020  01:19           159.790 pubfood.jpeg
# 17.11.2020  01:19           107.157 ramen.jpeg
# 07.09.2025  13:45            93.450 Receipt-woolworth.jpg
# 31.08.2016  01:22            54.132 rot.jpg
# 19.08.2025  18:37           171.933 scan.jpeg
# 08.09.2016  08:12           216.727 scan.jpg
# 19.11.2020  00:52            24.612 scan2.jpeg
# 07.08.2016  23:16            14.373 shapes.jpg
# 30.08.2016  00:34            24.979 shapestomatch.jpg
# 01.10.2016  18:34            15.930 shapes_donut.jpg
# 15.09.2025  12:36            57.418 soaps.jpeg
# 31.08.2016  01:25           267.445 soduku.jpg
# 29.08.2016  19:15            33.893 someshapes.jpg
# 08.09.2016  23:09            88.164 Sunflowers.jpg
# 07.08.2012  23:13           892.047 tobago.jpg
# 17.11.2020  01:19           299.883 trees.jpeg
# 13.09.2016  04:45            59.281 truck.jpg
# 12.08.2016  02:28            57.173 Trump.jpg
# 16.09.2025  20:02            13.791 trump2.jpg
# 17.11.2020  01:18           216.209 view.jpeg
# 17.11.2020  01:20            79.703 Volleyball.jpeg
# 24.08.2017  12:38            16.195 waldo.jpg
# 27.08.2016  05:30           468.651 WaldoBeach.jpg
# 02.09.2016  07:34         8.131.690 walking.avi
# 22.04.2025  12:19            41.347 walking_people.jpg
# 27.08.2025  18:26            15.451 water_coins.jpg
# 07.09.2025  13:47            91.841 whatsapp_conv.jpeg
# 06.09.2025  23:08            17.368 woman.jpeg
#               99 File(s)     32.560.510 bytes
#                2 Dir(s)  1.133.302.288.384 bytes free

# %% [markdown]
# ### **Resimleri Yükleme(Loading Images)**

# %%
# 'imread' kullanarak bir görüntü yükleyin, görüntünün yolunu belirtin
image = cv2.imread('../files/images/castara.jpeg')
print("dtype:", image.dtype)
print("shape:", image.shape)
# image bir NumPy ndarray ve görüntü verisini içeren çok-boyutlu bir dizi olarak kullanılır.
# Out:
# dtype: uint8
# shape: (1280, 960, 3)

# %% [markdown]
# ### **Resimleri Görüntüleme (Displaying Images)**

# %%
from matplotlib import pyplot as plt
#Resmi matplotlib ile göster
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#plt.show()

#Jupyter Notebook/JupyterLab içinde Çoğu durumda plt.show() çağrısına gerek kalmaz. Son hücrede oluşturulan figürler otomatik olarak render edilir 
#ve çıktıda görüntülenir.
#Standalone Python scripti plt.show() olmadan program çalışır ve grafik penceresi açılmaz; script hemen sonlanır ve pencere hiç oluşmayabilir.

# %% [markdown]
# Resimlerimizi görüntülemeyi daha basit ve kolay hale getirmek için basit bir fonksiyon oluşturalım.

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
#Deneyelim
imshow("Displaying Our First Image", image)

# %% [markdown]
# ### **Resimleri Kaydetme (Saving Images)**

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output.jpg', image)

#hangi dizinde (klasörde) çalışıyorsanız o dizine kayıt yapacaktır. Çalıştığınız dizini görmek için şağıdaki kodu kullanabilirsiniz
#import os
#cwd = os.getcwd()
#print(cwd)
# Out:
# True

# %%
# Or save it as a PNG (Portable Network Graphics) which is a Lossless bitmap image format
cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# ### **Resim Boyutlarını Görüntüleme**

# %% [markdown]
# Bu işlemi gerçekleştirmek için numpy kullanmamız gerekiyor.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (1280, 960, 3)

# %%
#Boyuta erişmek için, basitçe 0, 1 veya 2 kullanarak indeksleyin.
image.shape[2]
# Out:
# 3

# %% [markdown]
# İlk boyutun yükseklik olduğunu ve 960 piksel olduğunu görebilirsiniz.
#
# İkinci boyut ise genişlik ve 1280 pikseldir.
#
# Bunları şu şekilde yazdırabiliriz:

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 1280 pixels
# Width of Image: 960 pixels
# Depth of Image: 3 colors components

# %%
from matplotlib import pyplot as plt
import matplotlib
print("matplotlib sürümü:", matplotlib.__version__)
# Out:
# matplotlib sürümü: 3.9.0
